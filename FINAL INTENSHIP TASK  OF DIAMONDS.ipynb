# %%
# NAME:Sahil Santosh Pawar
#21/B
#kse

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("diamonds.csv")
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# # 1.  Print the total number of entries in the dataset

# %%
print("Total number of entries:", len(df))
# Out:
# Total number of entries: 53940

# %% [markdown]
# # 2. Plot the distribution of diamond prices.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], kde=True, color='skyblue')
plt.title('Distribution of Diamond Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #  3. Calculate the average price for each cut and color.

# %%
average_prices = df.groupby(['cut', 'color'])['price'].mean().reset_index()

print(average_prices)
# Out:
#           cut color        price
# 0        Fair     D  4291.061350
# 1        Fair     E  3682.312500
# 2        Fair     F  3827.003205
# 3        Fair     G  4239.254777
# 4        Fair     H  5135.683168
# 5        Fair     I  4685.445714
# 6        Fair     J  4975.655462
# 7        Good     D  3405.382175
# 8        Good     E  3423.644159
# 9        Good     F  3495.750275
# 10       Good     G  4123.482204
# 11       Good     H  4276.254986
# 12       Good     I  5078.532567
# 13       Good     J  4574.172638
# 14      Ideal     D  2629.094566
# 15      Ideal     E  2597.550090
# 16      Ideal     F  3374.939362
# 17      Ideal     G  3720.706388
# 18      Ideal     H  3889.334831
# 19      Ideal     I  4451.970377
# 20      Ideal     J  4918.186384
# 21    Premium     D  3631.292576
# 22    Premium     E  3538.914420
# 23    Premium     F  4324.890176
# 24    Premium     G  4500.742134
# 25    Premium     H  5216.706780
# 26    Premium     I  5946.180672
# ...

# %% [markdown]
# # 4.Print the names of diamonds with the highest and lowest prices

# %%
highest_price_row = df.loc[df['price'].idxmax()]

# %%
lowest_price_row = df.loc[df['price'].idxmin()]

# %%
print("Diamond with the highest price:", highest_price_row['price'])
print("Diamond with the lowest price:", lowest_price_row['price'])
# Out:
# Diamond with the highest price: 18823
# Diamond with the lowest price: 326

# %% [markdown]
# #  5.Plot the average price by cut and color.

# %%
average_prices = df.groupby(['cut', 'color'])['price'].mean().reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=average_prices, x='cut', y='price', hue='color')
plt.title('Average Price by Cut and Color')
plt.xlabel('Cut')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# # 6.Calculate the correlation between diamond carat weight and price.

# %%
correlation = df['carat'].corr(df['price'])

print("Correlation between carat and price:", correlation)
# Out:
# Correlation between carat and price: 0.9813511707134119

# %% [markdown]
# #  7. Plot the distribution of diamond carat weights.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['carat'], bins=30, kde=True)
plt.title('Distribution of Diamond Carat Weights')
plt.xlabel('Carat Weight')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # 8. Print the names of diamonds with the highest and lowest carat weights.

# %%
highest_carat_row = df.loc[df['carat'].idxmax()]

# %%
lowest_price_row = df.loc[df['carat'].idxmin()]

# %%
print("Diamond with the highest price:", highest_price_row['carat'])
print("Diamond with the lowest price:", lowest_price_row['carat'])
# Out:
# Diamond with the highest price: 2.29
# Diamond with the lowest price: 0.2

# %% [markdown]
# # 9. Plot the distribution of diamond clarity levels.

# %%
data = {
    'carat': [0.23, 0.21, 0.23, 0.29, 0.31, 0.72, 0.72, 0.70, 0.86, 0.75],
    'cut': ['Ideal', 'Premium', 'Good', 'Premium', 'Good', 'Ideal', 'Good', 'Very Good', 'Premium', 'Ideal'],
    'color': ['E', 'E', 'E', 'I', 'J', 'D', 'D', 'D', 'H', 'D'],
    'clarity': ['SI2', 'SI1', 'VS1', 'VS2', 'SI2', 'SI1', 'SI1', 'SI1', 'SI2', 'SI2'],
    'depth': [61.5, 59.8, 56.9, 62.4, 63.3, 60.8, 63.1, 62.8, 61.0, 62.2],
    'table': [55.0, 61.0, 65.0, 58.0, 58.0, 57.0, 55.0, 60.0, 58.0, 55.0],
    'price': [326, 326, 327, 334, 335, 2757, 2757, 2757, 2757, 2757],
    'x': [3.95, 3.89, 4.05, 4.20, 4.34, 5.75, 5.69, 5.66, 6.15, 5.83],
    'y': [3.98, 3.84, 4.07, 4.23, 4.35, 5.76, 5.75, 5.68, 6.12, 5.87],
    'z': [2.43, 2.31, 2.31, 2.63, 2.75, 3.50, 3.61, 3.56, 3.74, 3.64]
}

# %%
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='clarity', order=sorted(df['clarity'].unique()))
plt.title('Distribution of Diamond Clarity Levels')
plt.xlabel('Clarity Level')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # 10. Calculate the average price by clarity level.

# %%
average_price_by_clarity = df.groupby('clarity')['price'].mean()

print(average_price_by_clarity)
# Out:
# clarity
# SI1    2149.25
# SI2    1543.75
# VS1     327.00
# VS2     334.00
# Name: price, dtype: float64

# %% [markdown]
# # 11. Print the names of diamonds with the highest and lowest price-per-carat.

# %%
df['price_per_carat'] = df['price'] / df['carat']

# %%
highest_ppc_row = df.loc[df['price_per_carat'].idxmax()]

# %%
lowest_ppc_row = df.loc[df['price_per_carat'].idxmin()]

# %%
print("Diamond with the highest price-per-carat:", highest_ppc_row['carat'])
print("Diamond with the lowest price-per-carat:", lowest_ppc_row['carat'])
# Out:
# Diamond with the highest price-per-carat: 0.7
# Diamond with the lowest price-per-carat: 0.31

# %% [markdown]
# # 12. Plot the distribution of diamond prices by clarity level.

# %%
data = {
    'carat': [0.23, 0.21, 0.23, 0.29, 0.31, 0.72, 0.72, 0.70, 0.86, 0.75],
    'cut': ['Ideal', 'Premium', 'Good', 'Premium', 'Good', 'Ideal', 'Good', 'Very Good', 'Premium', 'Ideal'],
    'color': ['E', 'E', 'E', 'I', 'J', 'D', 'D', 'D', 'H', 'D'],
    'clarity': ['SI2', 'SI1', 'VS1', 'VS2', 'SI2', 'SI1', 'SI1', 'SI1', 'SI2', 'SI2'],
    'depth': [61.5, 59.8, 56.9, 62.4, 63.3, 60.8, 63.1, 62.8, 61.0, 62.2],
    'table': [55.0, 61.0, 65.0, 58.0, 58.0, 57.0, 55.0, 60.0, 58.0, 55.0],
    'price': [326, 326, 327, 334, 335, 2757, 2757, 2757, 2757, 2757],
    'x': [3.95, 3.89, 4.05, 4.20, 4.34, 5.75, 5.69, 5.66, 6.15, 5.83],
    'y': [3.98, 3.84, 4.07, 4.23, 4.35, 5.76, 5.75, 5.68, 6.12, 5.87],
    'z': [2.43, 2.31, 2.31, 2.63, 2.75, 3.50, 3.61, 3.56, 3.74, 3.64]
}

# %%
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='clarity', y='price')
plt.title('Distribution of Diamond Prices by Clarity Level')
plt.xlabel('Clarity Level')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# # 13. Calculate the median price for each cut and color.

# %%
median_price_by_cut_color = df.groupby(['cut', 'color'])['price'].median()

print(median_price_by_cut_color)
# Out:
# cut        color
# Good       D        2757.0
#            E         327.0
#            J         335.0
# Ideal      D        2757.0
#            E         326.0
# Premium    E         326.0
#            H        2757.0
#            I         334.0
# Very Good  D        2757.0
# Name: price, dtype: float64

# %% [markdown]
# # 14. Print the names of diamonds with the highest and lowest price-per-carat for each clarity level.

# %%
df['price_per_carat'] = df['price'] / df['carat']

# %%
grouped_data = df.groupby('clarity')

# %%
for clarity_level, group_df in grouped_data:
     highest_ppc_row = group_df.loc[group_df['price_per_carat'].idxmax()]

# %%
 lowest_ppc_row = group_df.loc[group_df['price_per_carat'].idxmin()]

# %%
 print(f"For clarity level '{clarity_level}':")
# Out:
# For clarity level 'VS2':

# %%
print("Diamond with the highest price-per-carat:", highest_ppc_row['clarity'])
print("Diamond with the lowest price-per-carat:", lowest_ppc_row['clarity'])
print()
# Out:
# Diamond with the highest price-per-carat: VS2
# Diamond with the lowest price-per-carat: VS2

# %% [markdown]
# # 15. Plot the average price by cut and clarity.

# %%
average_price = df.groupby(['cut', 'clarity'])['price'].mean().reset_index()

# %%
pivot_table = average_price.pivot(index='cut', columns='clarity', values='price')

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, cmap='YlGnBu', annot=True, fmt=".2f")
plt.title('Average Price by Cut and Clarity')
plt.xlabel('Clarity')
plt.ylabel('Cut')
plt.show()
